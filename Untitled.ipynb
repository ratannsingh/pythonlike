# %%
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-185f7b4a90d0> in <module>()
# ----> 1 import matplotlib.py
#
# ImportError: No module named 'matplotlib.py'

# %%
import matplotlib.pyplot as plt
x1=[3,5,6,7]
y1=[3,4,5,6]
plt.title("this is graph all about my ")
plt.xlabel("distance")
plt.ylabel("time")
plt.plot(x,y,color='b')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-14b6b0901106> in <module>()
#       5 plt.xlabel("distance")
#       6 plt.ylabel("time")
# ----> 7 plt.plot(x,y,color='b')
#       8 plt.show()
#
# NameError: name 'x' is not defined

# %%
import matplotlib.pyplot as plt
x1=[3,5,6,7]
y1=[3,4,5,6]
plt.title("this is graph between distance and time")
plt.xlabel("distance")
plt.ylabel("time")
plt.plot(x1,y1,color='b')
plt.grid(True,color='r')
plt.show()

# %%
import matplotlib.pyplot as plt
x1=[3,5,6,7]
y1=[3,4,5,6]
plt.title("this is graph between distance and time")
plt.xlabel("distance")
plt.ylabel("time")
plt.bar(x,y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-aeb74906faf4> in <module>()
#       5 plt.xlabel("distance")
#       6 plt.ylabel("time")
# ----> 7 plt.bar(x,y)
#
# NameError: name 'x' is not defined

# %% [markdown]
# # import matplotlib.pyplot as plt
# x1=[3,5,6,7]
# y1=[3,4,5,6]
# plt.title("this is graph between distance and time")
# plt.xlabel("distance")
# plt.ylabel("time")
# plt.bar(x1,y1)

# %%
import matplotlib.pyplot as plt
x1=[3,5,6,7]
y1=[3,4,5,6]
plt.title("this is graph between distance and time")
plt.xlabel("distance")
plt.ylabel("time")
plt.bar(x1,y1,label="danger region")
plt.legend()
plt.grid(True,color='r')

plt.show()
